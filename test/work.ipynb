# %%
from History import plot
import os
# %matplotlib inline

# %%
plot('./saved_model/base_v2')
# Out:
# base_v2-train base_v2-valid

# %%
'c' in a
# Out:
# False

# %%
a = list(range(10))
10 in a
# Out:
# False
